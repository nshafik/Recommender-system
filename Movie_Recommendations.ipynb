# %% [markdown]
# ## Movie Recommendation System

# %% [markdown]
# ### Installing Data

# %% [markdown]
#  Data Source : https://www.kaggle.com/netflix-inc/netflix-prize-data

# %% [markdown]
# #### Data Preproccessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
from scipy import sparse
from scipy.sparse import csr_matrix

from sklearn.decomposition import TruncatedSVD
from sklearn.metrics.pairwise import cosine_similarity
import random

# %%
def readFile(file_path, rows=100000):
    data_dict = {'Cust_Id' : [], 'Rating' : [],  'Movie_Id' : []}
    f = open(file_path, "r")
    count = 0
    for line in f:
        count += 1
        if count > rows:
            break
            
        if ':' in line:
            movidId = line[:-2] # remove the last character ':'
            movieId = int(movidId)
        else:
            customerID, rating, date = line.split(',')
            data_dict['Cust_Id'].append(customerID)
            data_dict['Rating'].append(rating)
            data_dict['Movie_Id'].append(movieId)
    f.close()
            
    return pd.DataFrame(data_dict)
df1 = readFile('../Data/Netflix/combined_data_1.txt', rows=100000)
df2 = readFile('../Data/Netflix/combined_data_2.txt', rows=100000)
df3 = readFile('../Data/Netflix/combined_data_3.txt', rows=100000)
df4 = readFile('../Data/Netflix/combined_data_4.txt', rows=100000)
df1['Rating'] = df1['Rating'].astype(float)
df2['Rating'] = df2['Rating'].astype(float)
df3['Rating'] = df3['Rating'].astype(float)
df4['Rating'] = df4['Rating'].astype(float)

# %%
df=df1
df.append(df2)
df.append(df3)
df.append(df4)
df.head()
# Out:
#    Cust_Id  Rating  Movie_Id
# 0  1488844     3.0         1
# 1   822109     5.0         1
# 2   885013     4.0         1
# 3    30878     4.0         1
# 4   823519     3.0         1

# %%
print("Total Data:")
print("Total number of movie ratings = "+str(df.shape[0]))
print("Number of unique users = "+str(len(np.unique(df["Cust_Id"]))))
print("Number of unique movies = "+str(len(np.unique(df["Movie_Id"]))))
# Out:
# Total Data:
# Total number of movie ratings = 99970
# Number of unique users = 81472
# Number of unique movies = 30

# %%
df_title = pd.read_csv('../Data/Netflix/movie_titles.csv', encoding = "ISO-8859-1", header = None, names = ['Movie_Id', 'Year', 'Name'])
df_title.head()
# Out:
#    Movie_Id    Year                          Name
# 0         1  2003.0               Dinosaur Planet
# 1         2  2004.0    Isle of Man TT 2004 Review
# 2         3  1997.0                     Character
# 3         4  1994.0  Paula Abdul's Get Up & Dance
# 4         5  2004.0      The Rise and Fall of ECW

# %%
df = pd.merge(df,df_title,on='Movie_Id')
df.head()
# Out:
#    Cust_Id  Rating  Movie_Id    Year             Name
# 0  1488844     3.0         1  2003.0  Dinosaur Planet
# 1   822109     5.0         1  2003.0  Dinosaur Planet
# 2   885013     4.0         1  2003.0  Dinosaur Planet
# 3    30878     4.0         1  2003.0  Dinosaur Planet
# 4   823519     3.0         1  2003.0  Dinosaur Planet

# %%
df.groupby('Name')['Rating'].count().sort_values(ascending=False).head()
# Out:
# Name
# Lilo and Stitch               39752
# What the #$*! Do We Know!?    14910
# Immortal Beloved              10722
# Something's Gotta Give         7172
# 7 Seconds                      7108
# Name: Rating, dtype: int64

# %%
df.groupby('Name')['Rating'].mean().sort_values(ascending=False).head()
# Out:
# Name
# Lord of the Rings: The Return of the King: Extended Edition: Bonus Material    4.552000
# Inspector Morse 31: Death Is Now My Neighbour                                  3.970174
# The Rise and Fall of ECW                                                       3.919298
# Lilo and Stitch                                                                3.823254
# Immortal Beloved                                                               3.784369
# Name: Rating, dtype: float64

# %%
util_mat = df.pivot_table(index = 'Cust_Id', columns = 'Name', values = 'Rating')
util_mat.head()
# Out:
# Name     7 Seconds  8 Man  Boycott  By Dawn's Early Light  Character  \
# Cust_Id
# 100006         NaN    NaN      NaN                    NaN        3.0
# 1000079        NaN    NaN      NaN                    NaN        NaN
# 1000105        NaN    NaN      NaN                    NaN        NaN
# 1000158        NaN    NaN      NaN                    NaN        NaN
# 1000192        NaN    NaN      NaN                    NaN        NaN
#
# Name     Chump Change  Class of Nuke 'Em High 2  \
# Cust_Id
# 100006            NaN                       NaN
# 1000079           NaN                       NaN
# 1000105           NaN                       NaN
# 1000158           NaN                       NaN
# 1000192           NaN                       NaN
#
# Name     Clifford: Clifford Saves the Day! / Clifford's Fluffiest Friend Cleo  \
# Cust_Id
# 100006                                                 NaN
# 1000079                                                NaN
# 1000105                                                NaN
# 1000158                                                NaN
# 1000192                                                NaN
#
# Name     Dinosaur Planet  Fighter  ...  Never Die Alone  \
# Cust_Id                            ...
# 100006               NaN      NaN  ...              NaN
# 1000079              NaN      NaN  ...              NaN
# 1000105              NaN      NaN  ...              NaN
# 1000158              NaN      NaN  ...              NaN
# 1000192              NaN      NaN  ...              NaN
#
# Name     Paula Abdul's Get Up & Dance  Screamers  Seeta Aur Geeta  \
# Cust_Id
# 100006                            NaN        NaN              NaN
# 1000079                           NaN        NaN              NaN
# 1000105                           NaN        NaN              NaN
# 1000158                           NaN        NaN              NaN
# 1000192                           NaN        NaN              NaN
#
# Name     Sesame Street: Elmo's World: The Street We Live On  Sick  \
# Cust_Id
# 100006                                                 NaN    NaN
# 1000079                                                NaN    NaN
# 1000105                                                NaN    NaN
# 1000158                                                NaN    NaN
# 1000192                                                NaN    NaN
#
# Name     Something's Gotta Give  Strange Relations  The Rise and Fall of ECW  \
# Cust_Id
# 100006                      NaN                NaN                       NaN
# 1000079                     NaN                NaN                       NaN
# 1000105                     NaN                NaN                       NaN
# 1000158                     NaN                NaN                       NaN
# 1000192                     NaN                NaN                       NaN
#
# Name     What the #$*! Do We Know!?
# Cust_Id
# 100006                          NaN
# 1000079                         NaN
# 1000105                         NaN
# 1000158                         NaN
# 1000192                         NaN
#
# [5 rows x 30 columns]

# %%
type(util_mat)
# Out:
# pandas.core.frame.DataFrame

# %%
item_util_matrix = util_mat.copy()

# We will fill the row wise NaN's with the corresponding user's mean ratings, so that we can carry out Pearson correlation.
# Here we assume avg ratings for the movie that is not rated.
item_util_matrix = item_util_matrix.apply(lambda col: col.fillna(col.mean()), axis=0)
item_util_matrix.head()
# Out:
# Name     7 Seconds     8 Man  Boycott  By Dawn's Early Light  Character  \
# Cust_Id
# 100006    2.903208  2.129032  3.59847               3.324675   3.000000
# 1000079   2.903208  2.129032  3.59847               3.324675   3.641153
# 1000105   2.903208  2.129032  3.59847               3.324675   3.641153
# 1000158   2.903208  2.129032  3.59847               3.324675   3.641153
# 1000192   2.903208  2.129032  3.59847               3.324675   3.641153
#
# Name     Chump Change  Class of Nuke 'Em High 2  \
# Cust_Id
# 100006       2.246305                  2.621053
# 1000079      2.246305                  2.621053
# 1000105      2.246305                  2.621053
# 1000158      2.246305                  2.621053
# 1000192      2.246305                  2.621053
#
# Name     Clifford: Clifford Saves the Day! / Clifford's Fluffiest Friend Cleo  \
# Cust_Id
# 100006                                            3.556098
# 1000079                                           3.556098
# 1000105                                           3.556098
# 1000158                                           3.556098
# 1000192                                           3.556098
#
# Name     Dinosaur Planet   Fighter  ...  Never Die Alone  \
# Cust_Id                             ...
# 100006          3.749543  3.180723  ...         2.793721
# 1000079         3.749543  3.180723  ...         2.793721
# 1000105         3.749543  3.180723  ...         2.793721
# 1000158         3.749543  3.180723  ...         2.793721
# 1000192         3.749543  3.180723  ...         2.793721
#
# Name     Paula Abdul's Get Up & Dance  Screamers  Seeta Aur Geeta  \
# Cust_Id
# 100006                       2.739437   3.098555         3.146552
# 1000079                      2.739437   3.098555         3.146552
# 1000105                      2.739437   3.098555         3.146552
# 1000158                      2.739437   3.098555         3.146552
# 1000192                      2.739437   3.098555         3.146552
#
# Name     Sesame Street: Elmo's World: The Street We Live On      Sick  \
# Cust_Id
# 100006                                            3.527473   3.084396
# 1000079                                           3.527473   3.084396
# 1000105                                           3.527473   3.084396
# 1000158                                           3.527473   3.084396
# 1000192                                           3.527473   3.084396
#
# Name     Something's Gotta Give  Strange Relations  The Rise and Fall of ECW  \
# Cust_Id
# 100006                 3.758226           3.463303                  3.919298
# 1000079                3.758226           3.463303                  3.919298
# 1000105                3.758226           3.463303                  3.919298
# 1000158                3.758226           3.463303                  3.919298
# 1000192                3.758226           3.463303                  3.919298
#
# Name     What the #$*! Do We Know!?
# Cust_Id
# 100006                     3.189805
# 1000079                    3.189805
# 1000105                    3.189805
# 1000158                    3.189805
# 1000192                    3.189805
#
# [5 rows x 30 columns]

# %%
item_util_matrix.isna().sum().sum()
# Out:
# 0

# %%
item_corr_matrix = item_util_matrix.corr()

# %%
item_corr_matrix.head()
# Out:
# Name                   7 Seconds     8 Man   Boycott  By Dawn's Early Light  \
# Name
# 7 Seconds               1.000000  0.014689  0.017389               0.010115
# 8 Man                   0.014689  1.000000  0.050871               0.051361
# Boycott                 0.017389  0.050871  1.000000               0.084472
# By Dawn's Early Light   0.010115  0.051361  0.084472               1.000000
# Character               0.006853  0.031564  0.059338               0.051568
#
# Name                   Character  Chump Change  Class of Nuke 'Em High 2  \
# Name
# 7 Seconds               0.006853      0.002539                  0.003418
# 8 Man                   0.031564      0.019776                  0.024524
# Boycott                 0.059338      0.015542                  0.041833
# By Dawn's Early Light   0.051568      0.019393                  0.022737
# Character               1.000000      0.013345                  0.023180
#
# Name                   Clifford: Clifford Saves the Day! / Clifford's Fluffiest Friend Cleo  \
# Name
# 7 Seconds                                                       0.009068
# 8 Man                                                           0.067978
# Boycott                                                         0.072160
# By Dawn's Early Light                                           0.064702
# Character                                                       0.041292
#
# Name                   Dinosaur Planet   Fighter  ...  Never Die Alone  \
# Name                                              ...
# 7 Seconds                     0.005539  0.009481  ...         0.047314
# 8 Man                         0.058701  0.053807  ...         0.012755
# Boycott                       0.043366  0.050144  ...         0.033329
# By Dawn's Early Light         0.038627  0.050087  ...         0.010470
# Character                     0.035760  0.062310  ...         0.009064
#
# Name                   Paula Abdul's Get Up & Dance  Screamers  \
# Name
# 7 Seconds                                  0.006895   0.013027
# 8 Man                                      0.034086   0.057651
# Boycott                                    0.030638   0.017198
# By Dawn's Early Light                      0.035622   0.024103
# Character                                  0.023800   0.010179
#
# Name                   Seeta Aur Geeta  \
# Name
# 7 Seconds                     0.007355
# 8 Man                         0.067369
# Boycott                       0.072136
# By Dawn's Early Light         0.073294
# Character                     0.048018
#
# Name                   Sesame Street: Elmo's World: The Street We Live On  \
# Name
# 7 Seconds                                                       0.013739
# 8 Man                                                           0.053334
# Boycott                                                         0.080414
# By Dawn's Early Light                                           0.074011
# Character                                                       0.051062
#
# Name                       Sick  Something's Gotta Give  Strange Relations  \
# Name
# 7 Seconds              0.004090                0.006654           0.007741
# 8 Man                  0.018826                0.000279          -0.002641
# Boycott                0.060476                0.002543           0.072615
# By Dawn's Early Light  0.029957               -0.001450           0.089208
# Character              0.035808                0.001730           0.061690
#
# Name                   The Rise and Fall of ECW  What the #$*! Do We Know!?
# Name
# 7 Seconds                              0.011152                    0.005469
# 8 Man                                  0.029554                    0.006465
# Boycott                                0.068024                    0.013735
# By Dawn's Early Light                  0.045883                    0.012773
# Character                              0.050896                    0.013678
#
# [5 rows x 30 columns]

# %%
def moviecorr(moviename):
    movie_corr = item_corr_matrix[str(moviename)]
    movie_corr = movie_corr.sort_values(ascending=False)
    movie_corr.dropna(inplace=True)
    movie_corr = pd.DataFrame(movie_corr)


    return movie_corr.drop(labels=str(moviename),).head()

# %%
moviecorr('The Rise and Fall of ECW')
# Out:
#                                                     The Rise and Fall of ECW
# Name
# Isle of Man TT 2004 Review                                          0.158534
# Sesame Street: Elmo's World: The Street We Live On                  0.086018
# Seeta Aur Geeta                                                     0.068152
# Boycott                                                             0.068024
# Dinosaur Planet                                                     0.054877

# %%
id_util_mat=util_mat.T
id_util_mat = id_util_mat.apply(lambda col: col.fillna(col.mean()), axis=0)

# %%
id_util_mat_1 = id_util_mat.iloc[:10000,:10000]
#id_util_mat_2 = id_util_mat.iloc[10000:20000,10000:20000]
#id_util_mat_3 = id_util_mat.iloc[20000:30000,20000:30000]
#id_util_mat_4 = id_util_mat.iloc[30000:40000,30000:40000]
#id_util_mat_5 = id_util_mat.iloc[40000:50000,40000:50000]
#id_util_mat_6 = id_util_mat.iloc[50000:60000,50000:60000]
#id_util_mat_7 = id_util_mat.iloc[60000:70000,60000:70000]
#id_util_mat_8 = id_util_mat.iloc[70000:,70000:]

# %%
id_util_mat_1=id_util_mat_1.corr()
#id_util_mat_2=id_util_mat_2.corr()
#id_util_mat_3=id_util_mat_3.corr()
#id_util_mat_4=id_util_mat_4.corr()
#id_util_mat_5=id_util_mat_5.corr()
#id_util_mat_6=id_util_mat_6.corr()
#id_util_mat_7=id_util_mat_7.corr()
#id_util_mat_8=id_util_mat_8.corr()

# %%
id_util_mat_1.head()
# Out:
# Cust_Id                100006  1000079  1000105  1000158  1000192  1000232  \
# Name
# 7 Seconds                 3.0      2.0      4.0      3.0      2.0      5.0
# 8 Man                     3.0      2.0      4.0      3.0      2.0      5.0
# Boycott                   3.0      2.0      4.0      3.0      2.0      5.0
# By Dawn's Early Light     3.0      2.0      4.0      3.0      2.0      5.0
# Character                 3.0      2.0      4.0      3.0      2.0      5.0
#
# Cust_Id                100029  1000301  1000303  1000328  ...  1292216  \
# Name                                                      ...
# 7 Seconds                 5.0      3.5      3.0      2.0  ...      3.0
# 8 Man                     5.0      3.5      3.0      2.0  ...      3.0
# Boycott                   5.0      3.5      3.0      2.0  ...      3.0
# By Dawn's Early Light     5.0      3.5      3.0      2.0  ...      3.0
# Character                 5.0      3.5      3.0      2.0  ...      3.0
#
# Cust_Id                1292272  1292299  1292338  1292345  1292357  1292384  \
# Name
# 7 Seconds                  5.0      3.0      3.0      4.0      2.0      4.0
# 8 Man                      5.0      3.0      3.0      4.0      2.0      4.0
# Boycott                    5.0      3.0      3.0      4.0      2.0      4.0
# By Dawn's Early Light      5.0      3.0      3.0      4.0      2.0      4.0
# Character                  5.0      3.0      3.0      4.0      2.0      4.0
#
# Cust_Id                1292387  129250  1292571
# Name
# 7 Seconds                  2.0     3.0      3.0
# 8 Man                      2.0     3.0      3.0
# Boycott                    2.0     3.0      3.0
# By Dawn's Early Light      2.0     3.0      3.0
# Character                  2.0     3.0      3.0
#
# [5 rows x 10000 columns]

# %%
def idcorr(moviename):
    id_corr = id_util_mat_1[str(moviename)]
    id_corr = id_corr.sort_values(ascending=False)
    id_corr.dropna(inplace=True)
    id_corr = pd.DataFrame(id_corr)


    return id_corr.drop(labels=str(moviename),).head()

# %%
id_corr = id_util_mat_1['1000105']
id_corr = id_corr.sort_values(ascending=False)
id_corr.dropna(inplace=True)
id_corr = pd.DataFrame(id_corr)

id_corr.head()
# Out:
#                             1000105
# Name
# What the #$*! Do We Know!?      4.0
# The Rise and Fall of ECW        4.0
# 8 Man                           4.0
# Boycott                         4.0
# By Dawn's Early Light           4.0

# %%
i
